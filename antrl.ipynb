# %%
import antlr4
from antlr4 import *
from BSLLexer import BSLLexer
from BSLParser import BSLParser
from BSLParserVisitor import BSLParserVisitor

input_stream = FileStream('ObjectModule.bsl', encoding='utf-8')
lexer = BSLLexer(input_stream)
stream = CommonTokenStream(lexer)
parser = BSLParser(stream)
tree = parser.file_()  # Пример именования стартового правила

# %%
from BSLMethodDescriptionLexer import BSLMethodDescriptionLexer
from BSLMethodDescriptionParser import BSLMethodDescriptionParser
from BSLMethodDescriptionParserVisitor import BSLMethodDescriptionParserVisitor
from antlr4 import InputStream

# %%
class MethodVisitor(BSLMethodDescriptionParserVisitor):
    def __init__(self):
        self.parse_dict={
            
        }

    def visitDeprecate(self, ctx):
        self.parse_dict.update({'deprecate': ctx.getText()})

    def visitDescriptionBlock(self, ctx):
        self.parse_dict.update({'descriptionBlock': ctx.getText()})
    
    def visitParameters(self, ctx):
        self.parse_dict.update({'parameters': ctx.getText()})
    
    def visitCallOptions(self, ctx):
        self.parse_dict.update({'callOptions': ctx.getText()})

# %%
def parse_comment(comment):
    string_stream = InputStream(comment)
    method_lexer = BSLMethodDescriptionLexer(string_stream)
    method_stream = CommonTokenStream(method_lexer)
    method_parser = BSLMethodDescriptionParser(method_stream)
    tree = method_parser.methodDescription()  # Пример именования стартового правила

    visitor = MethodVisitor()
    visitor.visit(tree)

    return visitor.parse_dict

# %%
"""parse_comment('//Hello, world \n// Параметры:\n // Устарела')"""
# Out:
# "parse_comment('//Hello, world \n// Параметры:\n // Устарела')"

# %%
def get_comments_above(ctx):
    met_non_empty_flag = False
    res_str = ""
    token_list = [item.text for item in [token for token in stream.getHiddenTokensToLeft(ctx.start.tokenIndex)]]
    for token in reversed(token_list):
        if '\n' in token:
            if met_non_empty_flag:
                break
        else:
            met_non_empty_flag = True
            res_str = ('\n'.join((res_str, token)) if res_str != '' else token)

    
    return res_str, parse_comment(res_str)

# %%
from BSLParser import BSLParser


class MyVisitor(BSLParserVisitor):
    def __init__(self, lexer):
        self.codeflow = list()
        self.childrenflow = list()
        self.lexer = lexer

    def visitTerminal(self, node):
        if node.symbol.type in [self.lexer.IF_KEYWORD, self.lexer.ELSE_KEYWORD, self.lexer.FOR_KEYWORD]: # предполагая, что IF, ELSE, FOR - константы токенов в вашем лексере
            print(f"KEYWORD'{node.getText()}") # модифицируем вывод
        else:
            print(node.getText())

# %%
keyws = set([
    "PROCEDURE",
    "FUNCTION",
    "ENDPROCEDURE",
    "ENDFUNCTION",
    "EXPORT",
    "VAL",
    "ENDIF",
    "ENDDO",
    "IF",
    "ELSIF",
    "ELSE",
    "THEN",
    "WHILE",
    "DO",
    "FOR",
    "TO",
    "EACH",
    "IN",
    "TRY",
    "EXCEPT",
    "ENDTRY",
    "RETURN",
    "CONTINUE",
    "RAISE",
    "VAR",
    "NOT",
    "OR",
    "AND",
    "NEW",
    "GOTO",
    "BREAK",
    "EXECUTE",
    "ADDHANDLER",
    "REMOVEHANDLER",
    "ASYNC"
])


def build_keyw_set(keyws, lexer, add_tokens=['LINE_COMMENT', ], add_preproc=False):
    keyws = set([
        getattr(lexer, kw + '_KEYWORD')
        for kw in keyws
    ] + [getattr(lexer, tok) for tok in add_tokens])
    return keyws

# %%
obj_keyws = build_keyw_set(keyws, lexer)

# %%
from antlr4.tree.Tree import TerminalNodeImpl

# Получение стартового токена для узла, относящегося к произвольному правилу
def getStartTok(node):
    """
    Получает индекс стартового токена для заданного узла дерева разбора,
    будь то контекстный узел или терминальный узел.
    
    Аргументы:
        node: Узел дерева разбора (RuleContext или TerminalNode).
        
    Возвращает:
        int: Индекс стартового токена данного узла.
    """
    if hasattr(node, 'symbol'):  # Для терминальных узлов
        return node.symbol.tokenIndex
    elif hasattr(node, 'start'):  # Для контекстных узлов
        return node.start.tokenIndex
    else:
        return None  # В случае, если у узла нет доступного стартового токена

# %%
import regex as re


def find_first_non_space(text):
    # Регулярное выражение для поиска пробельных символов и комментарив, чередующихся в любом порядке
    pattern = re.compile(r"(//.*\n|\s+)*")
    match = pattern.match(text)
    
    # Возвращаем индекс первого символа, не соответствующего шаблону
    if not match:
        return 0

    res = match.end()
    if res == len(text):
        return -1
    return res

# %%
find_first_non_space('   ')
# Out:
# -1

# %%
class UniversalVisitor(BSLParserVisitor):
    def __init__(self, stream, keyws=[]):
        self.codeflow = []
        self.defined_rule_mapping = {
            'ProcedureDeclarationCoreContext': 'PROC_DECL`',
            'FunctionDeclarationCoreContext': 'FUNC_DECL`',
            'ModuleVarDeclarationContext': 'VAR_NAME`',
            'SubVarDeclarationContext': 'VAR_NAME`',
            'DoCallContext': 'PARAM_LIST`',
            'AccessCallContext': 'ACCESS_CALL`',
            'MethodCall': 'METHOD_CALL`'
        }
        self.undefined_rule_mapping = {
            'SubNameContext': 'ID`',
            'ClosedParamListContext': 'ARGUMENTS`',
            'BeforeExecPartContext': 'ADDITIONAL_PART`'
        }
        self.undefined_prefix = {
            'FuncDeclarationContext': 'FUNC_',
            'ProcDeclarationContext': 'PROC_',
            'ProcedureDeclarationCoreContext': 'PROC_',
            'FunctionDeclarationCoreContext': 'FUNC_',
            '[default]': ''
        }
        self.keyws = keyws
        self.cur_father_node = '[default]'

        self.stream = stream

    def defaultResult(self):
        return ""

    def aggregateResult(self, aggregate, nextResult):
        #print(f'Aggregation: first = {aggregate}, second = {nextResult}')
        return aggregate + nextResult
    
    def visitTerminal(self, node):
        txt = node.getText()
        self.first_non_trash = 0
        if hasattr(node, 'symbol'):
            if (node.symbol.type in self.keyws):
                txt = 'KEYWORD`' + txt

            token_index = node.symbol.tokenIndex
            # Извлекаем токены из hidden channel, которые находятся слева от текущего токена
            hidden_tokens_to_left = self.stream.getHiddenTokensToLeft(token_index, antlr4.Lexer.HIDDEN) # 0 - это номер hiddenChannel
        
            # Добавляем текст каждого токена перед текущим токеном
            text = ''
            if hidden_tokens_to_left:
                for token in hidden_tokens_to_left:
                    text += token.text
            txt = text + txt

        return txt

    def visitChildren(self, node):
        # node – это текущий узел дерева
        name = node.__class__.__name__

        result = self.defaultResult()
        n = node.getChildCount()

        for i in range(n):
            c = node.getChild(i)
            # Рекурсивно посещаем всех детей узла
            prev_father = self.cur_father_node
            self.cur_father_node = name

            childResult = c.accept(self) #self.visitChildren(c, father_name=name)

            self.cur_father_node = prev_father
            result = self.aggregateResult(result, childResult)

        if name in self.defined_rule_mapping.keys():
            non_empty_idx = find_first_non_space(result)
            if non_empty_idx == -1:
                return result
            result = result[:non_empty_idx] + self.defined_rule_mapping[name] + result[non_empty_idx:]
        elif name in self.undefined_rule_mapping.keys():
            insertion = self.undefined_prefix[self.cur_father_node] + self.undefined_rule_mapping[name]
            non_empty_idx = find_first_non_space(result)
            if non_empty_idx == -1:
                return result
            result = result[:non_empty_idx] + insertion + result[non_empty_idx:]

        # Возвращаем ответ
        return result

# %%
vis = UniversalVisitor(
    stream,
    keyws=obj_keyws
)

# %%
out = vis.visit(tree)

# %%
print(out)
# Out:
# KEYWORD`Перем VAR_NAME`КэшПостроительДереваТестов;
# KEYWORD`Перем VAR_NAME`ЗагружаемыйПуть;
#
# KEYWORD`Перем VAR_NAME`КонтейнерТестов;
# KEYWORD`Перем VAR_NAME`ТекущаяГруппа;
#
# // { Plugin interface
# FUNC_DECL`KEYWORD`Функция FUNC_ID`ОписаниеПлагинаFUNC_ARGUMENTS`(ВозможныеТипыПлагинов) KEYWORD`Экспорт
# 	Результат = KEYWORD`Новый Структура;
# 	РезультатACCESS_CALL`.ВставитьPARAM_LIST`("Тип", ВозможныеТипыПлагинов.Загрузчик);
# 	РезультатACCESS_CALL`.ВставитьPARAM_LIST`("Идентификатор", МетаданныеPARAM_LIST`().Имя);
# 	РезультатACCESS_CALL`.ВставитьPARAM_LIST`("Представление", "Загрузить тесты из файлов");
# 	// Test Comment
# 	KEYWORD`Возврат KEYWORD`Новый ФиксированнаяСтруктураPARAM_LIST`(Результат);
# KEYWORD`КонецФункции
#
# PROC_DECL`KEYWORD`Процедура PROC_ID`ИнициализацияPROC_ARGUMENTS`(КонтекстЯдраПараметр) KEYWORD`Экспорт
# KEYWORD`КонецПроцедуры
#
# // } Plugin interface
#
# // { Loader interface
# FUNC_ADDITIONAL_PART`#Если ТолстыйКлиентОбычноеПриложение Тогда
# FUNC_DECL`KEYWORD`Функция FUNC_ID`ВыбратьПутьИнтерактивноFUNC_ARGUMENTS`(КонтекстЯдра, ТекущийПуть = "") KEYWORD`Экспорт
# 	ДиалогВыбораТеста = KEYWORD`Новый ДиалогВыбораФайлаPARAM_LIST`(РежимДиалогаВыбораФайла.Открытие);
# 	ДиалогВыбораТеста.Фильтр = "Обработка-тест (*.epf)|*.epf|Отчет-тест (*.erf)|*.erf|Все файлы|*";
# 	ДиалогВыбораТеста.МножественныйВыбор = Истина;
# 	ДиалогВыбораТеста.ПроверятьСуществованиеФайла = Истина;
# 	ДиалогВыбораТеста.ПолноеИмяФайла = ТекущийПуть;
#
# 	Результат = KEYWORD`Новый ТекстовыйДокумент;
# 	KEYWORD`Если ДиалогВыбораТестаACCESS_CALL`.ВыбратьPARAM_LIST`() KEYWORD`Тогда
# 		KEYWORD`Для KEYWORD`каждого ПолноеИмяФайла KEYWORD`Из ДиалогВыбораТеста.ВыбранныеФайлы KEYWORD`Цикл
# 			РезультатACCESS_CALL`.ДобавитьСтрокуPARAM_LIST`(ПолноеИмяФайла);
# 		KEYWORD`КонецЦикла;
# 	KEYWORD`КонецЕсли;
# 	Текст = РезультатACCESS_CALL`.ПолучитьТекстPARAM_LIST`();
#
# 	KEYWORD`Возврат ЛевPARAM_LIST`(Текст, СтрДлинаPARAM_LIST`(Текст) - 1);
# KEYWORD`КонецФункции
# FUNC_ADDITIONAL_PART`#КонецЕсли
#
# FUNC_DECL`KEYWORD`Функция FUNC_ID`ЗагрузитьFUNC_ARGUMENTS`(КонтекстЯдра, Путь) KEYWORD`Экспорт
# 	ПостроительДереваТестов = КонтекстЯдраACCESS_CALL`.ПлагинPARAM_LIST`("ПостроительДереваТестов");
# 	ДеревоТестов = Неопределено;
# 	KEYWORD`Для Сч = 1 KEYWORD`По СтрЧислоСтрокPARAM_LIST`(Путь) KEYWORD`Цикл
# 		ФайлОбработки = KEYWORD`Новый ФайлPARAM_LIST`(СтрПолучитьСтрокуPARAM_LIST`(Путь, Сч));
#
# 		KEYWORD`Если ДеревоТестов = Неопределено KEYWORD`Тогда
# 			ДеревоТестов = ПостроительДереваТестовACCESS_CALL`.СоздатьКонтейнерPARAM_LIST`(ФайлОбработки.Путь);
# 		KEYWORD`КонецЕсли;
#
# 		КонтейнерСТестамиОбработки = ЗагрузитьФайлPARAM_LIST`(ПостроительДереваТестов, ФайлОбработки, КонтекстЯдра);
# 		KEYWORD`Если КонтейнерСТестамиОбработки.СтрокиACCESS_CALL`.КоличествоPARAM_LIST`() > 0 KEYWORD`Тогда
# 			ДеревоТестов.СтрокиACCESS_CALL`.ДобавитьPARAM_LIST`(КонтейнерСТестамиОбработки);
# 		KEYWORD`КонецЕсли;
# 	KEYWORD`КонецЦикла;
#
# 	KEYWORD`Возврат ДеревоТестов;
# KEYWORD`КонецФункции
#
# FUNC_DECL`KEYWORD`Функция FUNC_ID`ПолучитьКонтекстПоПутиFUNC_ARGUMENTS`(КонтекстЯдра, Путь) KEYWORD`Экспорт
# 	ФайлОбработки = KEYWORD`Новый ФайлPARAM_LIST`(Путь);
#
# 	Обработка = ПолучитьКонтекстОбработкиPARAM_LIST`(ФайлОбработки);
#
# 	KEYWORD`Возврат Обработка;
# KEYWORD`КонецФункции
# // } Loader interface
#
# FUNC_DECL`KEYWORD`Функция FUNC_ID`ПолучитьКонтекстОбработкиFUNC_ARGUMENTS`(ФайлОбработки)
#
# 	ЭтоФайлОтчета = (НРегPARAM_LIST`(ФайлОбработки.Расширение) = ".erf");
#
# 	KEYWORD`Попытка
# 		KEYWORD`Если ЭтоФайлОтчета KEYWORD`Тогда
# 			Обработка = ВнешниеОтчетыACCESS_CALL`.СоздатьPARAM_LIST`(ФайлОбработки.ИмяБезРасширения, Ложь);
# 		KEYWORD`Иначе
# 			Обработка = ВнешниеОбработкиACCESS_CALL`.СоздатьPARAM_LIST`(ФайлОбработки.ИмяБезРасширения, Ложь);
# 		KEYWORD`КонецЕсли;
# 	KEYWORD`Исключение
# 		ПроверитьКорректностьФайлаPARAM_LIST`(ФайлОбработки);
#
# 		KEYWORD`Если ЭтоФайлОтчета KEYWORD`Тогда
# 			Обработка = ВнешниеОтчетыACCESS_CALL`.СоздатьPARAM_LIST`(ФайлОбработки.ПолноеИмя, Ложь);
# 		KEYWORD`Иначе
# 			Обработка = ВнешниеОбработкиACCESS_CALL`.СоздатьPARAM_LIST`(ФайлОбработки.ПолноеИмя, Ложь);
# 		KEYWORD`КонецЕсли;
# 	KEYWORD`КонецПопытки;
# 	KEYWORD`Возврат Обработка;
#
# KEYWORD`КонецФункции
#
# PROC_DECL`KEYWORD`Процедура PROC_ID`ПроверитьКорректностьФайлаPROC_ARGUMENTS`(Файл)
# 	KEYWORD`Если KEYWORD`Не ФайлACCESS_CALL`.СуществуетPARAM_LIST`() KEYWORD`Тогда
# 		KEYWORD`ВызватьИсключение "Переданный файл не существует файл <" + Файл.ПолноеИмя + ">";
# 	KEYWORD`КонецЕсли;
# 	KEYWORD`Если ФайлACCESS_CALL`.ЭтоКаталогPARAM_LIST`() KEYWORD`Тогда
# 		KEYWORD`ВызватьИсключение "Передан каталог вместо файла <" + Файл.ПолноеИмя + ">";
# 	KEYWORD`КонецЕсли;
# KEYWORD`КонецПроцедуры
#
# FUNC_DECL`KEYWORD`Функция FUNC_ID`ЗагрузитьФайлFUNC_ARGUMENTS`(ПостроительДереваТестов, ФайлОбработки, КонтекстЯдра) KEYWORD`Экспорт
# 	Обработка = ПолучитьКонтекстОбработкиPARAM_LIST`(ФайлОбработки);
# 	KEYWORD`Попытка
# 		Контейнер = ЗагрузитьТестыВНовомФорматеPARAM_LIST`(ПостроительДереваТестов, Обработка, ФайлОбработки, КонтекстЯдра);
# 	KEYWORD`Исключение
# 		ТекстОшибки = ПодробноеПредставлениеОшибкиPARAM_LIST`(ИнформацияОбОшибкеPARAM_LIST`());
# 		KEYWORD`Если ЭтоНовыйФорматОбработкиPARAM_LIST`(ТекстОшибки) KEYWORD`Тогда
# 			KEYWORD`ВызватьИсключение;
# 		KEYWORD`Иначе
# 			Контейнер = ЗагрузитьТестыВСтаромФорматеPARAM_LIST`(ПостроительДереваТестов, Обработка, ФайлОбработки);
# 		KEYWORD`КонецЕсли;
# 	KEYWORD`КонецПопытки;
#
# 	KEYWORD`Возврат Контейнер;
# KEYWORD`КонецФункции
#
# FUNC_DECL`KEYWORD`Функция FUNC_ID`ЗагрузитьТестыВНовомФорматеFUNC_ARGUMENTS`(ПостроительДереваТестов, Обработка, ФайлОбработки, КонтекстЯдра)
# 	ЗагружаемыйПуть = ФайлОбработки.ПолноеИмя;
# 	КэшПостроительДереваТестов = ПостроительДереваТестов;
# 	KEYWORD`Если НРегPARAM_LIST`(ФайлОбработки.Расширение) = ".erf" KEYWORD`Тогда
# 		ИконкаУзла = ПостроительДереваТестов.ИконкиУзловДереваТестов.Отчет;
# 	KEYWORD`Иначе
# 		ИконкаУзла = ПостроительДереваТестов.ИконкиУзловДереваТестов.Обработка;
# 	KEYWORD`КонецЕсли;
# 	КонтейнерТестов = ПостроительДереваТестовACCESS_CALL`.СоздатьКонтейнерPARAM_LIST`(ФайлОбработки.ИмяБезРасширения, ИконкаУзла);
#
# 	KEYWORD`Попытка
# 		ОбработкаACCESS_CALL`.ЗаполнитьНаборТестовPARAM_LIST`(ЭтотОбъект, КонтекстЯдра);
# 	KEYWORD`Исключение
# 		Инфо = ИнформацияОбОшибкеPARAM_LIST`();
# 		KEYWORD`Если Инфо.ИмяМодуля = "ВнешняяОбработка.ЗагрузчикФайла.МодульОбъекта" KEYWORD`И
# 			Инфо.Описание = "Слишком много фактических параметров" KEYWORD`И
# 			СтрНайтиPARAM_LIST`(Инфо.ИсходнаяСтрока, "Обработка.ЗаполнитьНаборТестов(ЭтотОбъект, КонтекстЯдра);") > 0
# 			KEYWORD`Тогда
#
# 				ОбработкаACCESS_CALL`.ЗаполнитьНаборТестовPARAM_LIST`(ЭтотОбъект);
#
# 			KEYWORD`Иначе
# 				KEYWORD`ВызватьИсключение;
# 			KEYWORD`КонецЕсли;
# 	KEYWORD`КонецПопытки;
#
# 	Результат = КонтейнерТестов;
# 	КонтейнерТестов = Неопределено;
# 	ТекущаяГруппа = Неопределено;
#
# 	KEYWORD`Возврат Результат;
# KEYWORD`КонецФункции
#
# FUNC_DECL`KEYWORD`Функция FUNC_ID`ЭтоНовыйФорматОбработкиFUNC_ARGUMENTS`(KEYWORD`Знач ТекстОшибки)
# 	ЭтоНовыйФорматОбработки = KEYWORD`Не ЕстьОшибка_МетодОбъектаНеОбнаруженPARAM_LIST`(ТекстОшибки, "ЗаполнитьНаборТестов");
#
# 	KEYWORD`Возврат ЭтоНовыйФорматОбработки;
# KEYWORD`КонецФункции
#
# FUNC_DECL`KEYWORD`Функция FUNC_ID`ЗагрузитьТестыВСтаромФорматеFUNC_ARGUMENTS`(ПостроительДереваТестов, Обработка, ФайлОбработки)
# 	KEYWORD`Попытка
# 		СписокТестов = ОбработкаACCESS_CALL`.ПолучитьСписокТестовPARAM_LIST`();
# 	KEYWORD`Исключение
# 		Описание = ОписаниеОшибкиPARAM_LIST`();
# 		KEYWORD`Если НайтиPARAM_LIST`(Описание, "Недостаточно фактических параметров") > 0 KEYWORD`Тогда
# 			KEYWORD`ВызватьИсключение "Старый формат тестов в обработке тестов <"+ФайлОбработки.ПолноеИмя+">."+Символы.ПС+
# 				"Метод ПолучитьСписокТестов сейчас не принимает параметров";
# 		KEYWORD`КонецЕсли;
#
# 		KEYWORD`Если НайтиPARAM_LIST`(Описание, "Метод объекта не обнаружен (ПолучитьСписокТестов)") = 0 KEYWORD`Тогда
# 			KEYWORD`ВызватьИсключение Описание;
# 		KEYWORD`КонецЕсли;
# 	KEYWORD`КонецПопытки;
#
# 	СлучайныйПорядокВыполнения = Истина;
# 	KEYWORD`Попытка
# 		СлучайныйПорядокВыполнения = ОбработкаACCESS_CALL`.РазрешенСлучайныйПорядокВыполненияТестовPARAM_LIST`();
# 	KEYWORD`Исключение
# 	KEYWORD`КонецПопытки;
# 	Результат = ПолучитьКонтейнерДереваТестовПоСпискуТестовPARAM_LIST`(ПостроительДереваТестов, СписокТестов, ФайлОбработки.ИмяБезРасширения, ФайлОбработки.ПолноеИмя, СлучайныйПорядокВыполнения);
#
# 	KEYWORD`Возврат Результат;
# KEYWORD`КонецФункции
#
# FUNC_DECL`KEYWORD`Функция FUNC_ID`ПолучитьКонтейнерДереваТестовПоСпискуТестовFUNC_ARGUMENTS`(ПостроительДереваТестов, СписокТестов, ИмяКонтейнера, Путь, СлучайныйПорядокВыполнения = Истина) KEYWORD`Экспорт
# 	Контейнер = ПостроительДереваТестовACCESS_CALL`.СоздатьКонтейнерPARAM_LIST`(ИмяКонтейнера, ПостроительДереваТестов.ИконкиУзловДереваТестов.Обработка);
# 	Контейнер.СлучайныйПорядокВыполнения = СлучайныйПорядокВыполнения;
# 	KEYWORD`Если ЗначениеЗаполненоPARAM_LIST`(СписокТестов) KEYWORD`И ТипЗнчPARAM_LIST`(СписокТестов) = ТипPARAM_LIST`("Массив") KEYWORD`Тогда
# 		KEYWORD`Для KEYWORD`каждого Тест KEYWORD`Из СписокТестов KEYWORD`Цикл
# 			Элемент = Неопределено;
# 			KEYWORD`Если ТипЗнчPARAM_LIST`(Тест) = ТипPARAM_LIST`("Строка") KEYWORD`Тогда
# 				Элемент = ПостроительДереваТестовACCESS_CALL`.СоздатьЭлементPARAM_LIST`(Путь, Тест);
# 			KEYWORD`ИначеЕсли ТипЗнчPARAM_LIST`(Тест) = ТипPARAM_LIST`("Структура") KEYWORD`Тогда
# 				ИмяМетода = Тест.ИмяТеста;
# 				Представление = Неопределено;
# 				KEYWORD`Если KEYWORD`Не ТестACCESS_CALL`.СвойствоPARAM_LIST`("ПредставлениеТеста", Представление) KEYWORD`Тогда
# 					Представление = ИмяМетода;
# 				KEYWORD`КонецЕсли;
# 				Элемент = ПостроительДереваТестовACCESS_CALL`.СоздатьЭлементPARAM_LIST`(Путь, ИмяМетода, Представление);
# 				Параметр = Неопределено;
# 				KEYWORD`Если ТестACCESS_CALL`.СвойствоPARAM_LIST`("Параметр", Параметр) KEYWORD`Тогда
# 					Элемент.ПараметрыACCESS_CALL`.ДобавитьPARAM_LIST`(Параметр);
# 				KEYWORD`КонецЕсли;
# 			KEYWORD`Иначе
# 				KEYWORD`ВызватьИсключение "Тест может быть описан либо строкой либо структурой";
# 			KEYWORD`КонецЕсли;
# 			KEYWORD`Если ЗначениеЗаполненоPARAM_LIST`(Элемент) KEYWORD`Тогда
# 				Контейнер.СтрокиACCESS_CALL`.ДобавитьPARAM_LIST`(Элемент);
# 			KEYWORD`КонецЕсли;
# 		KEYWORD`КонецЦикла;
# 	KEYWORD`КонецЕсли;
#
# 	KEYWORD`Возврат Контейнер;
# KEYWORD`КонецФункции
#
# // { API нового формата
# PROC_DECL`KEYWORD`Процедура PROC_ID`СлучайныйПорядокВыполненияPROC_ARGUMENTS`() KEYWORD`Экспорт
# 	KEYWORD`Если ЗначениеЗаполненоPARAM_LIST`(КонтейнерТестов) KEYWORD`Тогда
# 		КонтейнерТестов.СлучайныйПорядокВыполнения = Истина;
# 	KEYWORD`КонецЕсли;
# KEYWORD`КонецПроцедуры
#
# PROC_DECL`KEYWORD`Процедура PROC_ID`СтрогийПорядокВыполненияPROC_ARGUMENTS`() KEYWORD`Экспорт
# 	KEYWORD`Если ЗначениеЗаполненоPARAM_LIST`(КонтейнерТестов) KEYWORD`Тогда
# 		КонтейнерТестов.СлучайныйПорядокВыполнения = Ложь;
# 	KEYWORD`КонецЕсли;
# KEYWORD`КонецПроцедуры
#
# PROC_DECL`KEYWORD`Процедура PROC_ID`НачатьГруппуPROC_ARGUMENTS`(KEYWORD`Знач ИмяГруппы, KEYWORD`Знач СтрогийПорядокВыполнения = Ложь) KEYWORD`Экспорт
# 	ТекущаяГруппа = КэшПостроительДереваТестовACCESS_CALL`.СоздатьКонтейнерPARAM_LIST`(ИмяГруппы, КэшПостроительДереваТестов.ИконкиУзловДереваТестов.Группа);
# 	ТекущаяГруппа.Путь = ЗагружаемыйПуть;
# 	ТекущаяГруппа.СлучайныйПорядокВыполнения = KEYWORD`Не СтрогийПорядокВыполнения;
# 	КонтейнерТестов.СтрокиACCESS_CALL`.ДобавитьPARAM_LIST`(ТекущаяГруппа);
# KEYWORD`КонецПроцедуры
#
# FUNC_DECL`KEYWORD`Функция FUNC_ID`ДобавитьFUNC_ARGUMENTS`(KEYWORD`Знач ИмяМетода, KEYWORD`Знач Параметры = Неопределено, KEYWORD`Знач Представление = "") KEYWORD`Экспорт
# 	KEYWORD`Если KEYWORD`Не ЗначениеЗаполненоPARAM_LIST`(Параметры) KEYWORD`ИЛИ ТипЗнчPARAM_LIST`(Параметры) <> ТипPARAM_LIST`("Массив") KEYWORD`Тогда
# 		KEYWORD`Если ТипЗнчPARAM_LIST`(Параметры) = ТипPARAM_LIST`("Строка") KEYWORD`И Представление = "" KEYWORD`Тогда
# 			Представление = Параметры;
# 		KEYWORD`КонецЕсли;
# 		Параметры = Неопределено;
# 	KEYWORD`КонецЕсли;
# 	Элемент = КэшПостроительДереваТестовACCESS_CALL`.СоздатьЭлементPARAM_LIST`(ЗагружаемыйПуть, ИмяМетода, Представление);
# 	KEYWORD`Если Параметры <> Неопределено KEYWORD`Тогда
# 		Элемент.Параметры = Параметры;
# 	KEYWORD`КонецЕсли;
# 	KEYWORD`Если ЗначениеЗаполненоPARAM_LIST`(ТекущаяГруппа) KEYWORD`Тогда
# 		ТекущаяГруппа.СтрокиACCESS_CALL`.ДобавитьPARAM_LIST`(Элемент);
# 	KEYWORD`Иначе
# 		КонтейнерТестов.СтрокиACCESS_CALL`.ДобавитьPARAM_LIST`(Элемент);
# 	KEYWORD`КонецЕсли;
#
# 	KEYWORD`Возврат Элемент;
# KEYWORD`КонецФункции
#
# FUNC_DECL`KEYWORD`Функция FUNC_ID`ДобавитьДеструкторFUNC_ARGUMENTS`(KEYWORD`Знач ИмяМетодаДеструктора, KEYWORD`Знач Представление = "") KEYWORD`Экспорт
# 	ЭлементДеструктор = ДобавитьPARAM_LIST`(ИмяМетодаДеструктора, Неопределено, Представление);
# 	KEYWORD`Если ЗначениеЗаполненоPARAM_LIST`(ТекущаяГруппа) KEYWORD`Тогда
# 		ТекущаяГруппа.ЭлементДеструктор = ЭлементДеструктор;
# 	KEYWORD`Иначе
# 		КонтейнерТестов.ЭлементДеструктор = ЭлементДеструктор;
# 	KEYWORD`КонецЕсли;
# KEYWORD`КонецФункции
#
# FUNC_DECL`KEYWORD`Функция FUNC_ID`ПараметрыТестаFUNC_ARGUMENTS`(KEYWORD`Знач Парам1, KEYWORD`Знач Парам2 = Неопределено, KEYWORD`Знач Парам3 = Неопределено, KEYWORD`Знач Парам4 = Неопределено, KEYWORD`Знач Парам5 = Неопределено, KEYWORD`Знач Парам6 = Неопределено, KEYWORD`Знач Парам7 = Неопределено, KEYWORD`Знач Парам8 = Неопределено, KEYWORD`Знач Парам9 = Неопределено) KEYWORD`Экспорт
# 	ВсеПараметры = KEYWORD`Новый Массив;
# 	ВсеПараметрыACCESS_CALL`.ДобавитьPARAM_LIST`(Парам1);
# 	ВсеПараметрыACCESS_CALL`.ДобавитьPARAM_LIST`(Парам2);
# 	ВсеПараметрыACCESS_CALL`.ДобавитьPARAM_LIST`(Парам3);
# 	ВсеПараметрыACCESS_CALL`.ДобавитьPARAM_LIST`(Парам4);
# 	ВсеПараметрыACCESS_CALL`.ДобавитьPARAM_LIST`(Парам5);
# 	ВсеПараметрыACCESS_CALL`.ДобавитьPARAM_LIST`(Парам6);
# 	ВсеПараметрыACCESS_CALL`.ДобавитьPARAM_LIST`(Парам7);
# 	ВсеПараметрыACCESS_CALL`.ДобавитьPARAM_LIST`(Парам8);
# 	ВсеПараметрыACCESS_CALL`.ДобавитьPARAM_LIST`(Парам9);
#
# 	ИндексСПоследнимПараметром = 0;
# 	KEYWORD`Для Сч = 0 KEYWORD`По ВсеПараметрыACCESS_CALL`.ВГраницаPARAM_LIST`() KEYWORD`Цикл
# 		Индекс = ВсеПараметрыACCESS_CALL`.ВГраницаPARAM_LIST`() - Сч;
# 		KEYWORD`Если ВсеПараметры[Индекс] <> Неопределено KEYWORD`Тогда
# 			ИндексСПоследнимПараметром = Индекс;
# 			KEYWORD`Прервать;
# 		KEYWORD`КонецЕсли;
# 	KEYWORD`КонецЦикла;
#
# 	ПараметрыТеста = KEYWORD`Новый Массив;
# 	KEYWORD`Для Сч = 0 KEYWORD`По ИндексСПоследнимПараметром KEYWORD`Цикл
# 		ПараметрыТестаACCESS_CALL`.ДобавитьPARAM_LIST`(ВсеПараметры[Сч]);
# 	KEYWORD`КонецЦикла;
#
# 	KEYWORD`Возврат ПараметрыТеста;
# KEYWORD`КонецФункции
# // } API нового формата
#
# // { Helpers
# FUNC_DECL`KEYWORD`Функция FUNC_ID`ЕстьОшибка_МетодОбъектаНеОбнаруженFUNC_ARGUMENTS`(KEYWORD`Знач ТекстОшибки, KEYWORD`Знач ИмяМетода)
# 	Результат = Ложь;
# 	KEYWORD`Если НайтиPARAM_LIST`(текстОшибки, "Метод объекта не обнаружен (" + ИмяМетода + ")") > 0
# 		KEYWORD`ИЛИ НайтиPARAM_LIST`(текстОшибки, "Object method not found (" + ИмяМетода + ")") > 0  KEYWORD`Тогда
# 		Результат = Истина;
# 	KEYWORD`КонецЕсли;
#
# 	KEYWORD`Возврат Результат;
# KEYWORD`КонецФункции
# // } Helpers
# <EOF>

# %%
stream.channel
# Out:
# 0
